# %%
import pandas as pd

# %%
#Load dataset
data = pd.read_csv('shopping.csv')

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
# prompt: data.keys

data.keys()
item_counts = data['Item Purchased'].value_counts()
print(item_counts)
# Out:
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: Item Purchased, dtype: int64

# %%
data.shape
# Out:
# (3900, 18)

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Customer ID'].plot(kind='hist', bins=20, title='Customer ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Purchase Amount (USD)'].plot(kind='hist', bins=20, title='Purchase Amount (USD)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Review Rating'].plot(kind='hist', bins=20, title='Review Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Customer ID', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Age', y='Purchase Amount (USD)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Purchase Amount (USD)', y='Review Rating', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Review Rating', y='Previous Purchases', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Customer ID'].plot(kind='line', figsize=(8, 4), title='Customer ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Purchase Amount (USD)'].plot(kind='line', figsize=(8, 4), title='Purchase Amount (USD)')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Review Rating'].plot(kind='line', figsize=(8, 4), title='Review Rating')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
data.nunique()
# Out:
# Customer ID               3900
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Location                    50
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Shipping Type                6
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Payment Method               6
# Frequency of Purchases       7
# dtype: int64

# %%
data.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
data.drop_duplicates(inplace=True)

# %%
df = pd.DataFrame(data)
grouped_by_item = df.groupby('Item Purchased')
total_purchase_per_item = grouped_by_item['Purchase Amount (USD)'].sum()
print(total_purchase_per_item)
# Out:
# Item Purchased
# Backpack       8636
# Belt           9635
# Blouse        10410
# Boots          9018
# Coat           9275
# Dress         10320
# Gloves         8477
# Handbag        8857
# Hat            9375
# Hoodie         8767
# Jacket         9249
# Jeans          7548
# Jewelry       10010
# Pants         10090
# Sandals        9200
# Scarf          9561
# Shirt         10332
# Shoes          9240
# Shorts         9433
# Skirt          9402
# Sneakers       8635
# Socks          9252
# Sunglasses     9649
# Sweater        9462
# T-shirt        9248
# Name: Purchase Amount (USD), dtype: int64

# %%
# Create a pie chart of the total purchase amount per item
plt.figure(figsize=(8, 8))
plt.pie(total_purchase_per_item, labels=total_purchase_per_item.index, autopct="%1.1f%%", startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Total Purchase Amount per Item Purchased')
plt.show()

# %%
df = pd.DataFrame(data)
grouped_by_item = df.groupby('Item Purchased')
average_rating_per_item = grouped_by_item['Review Rating'].mean()
results = pd.DataFrame({'Item Purchased': average_rating_per_item.index, 'Average Rating': average_rating_per_item.values})
sorted_results = results.sort_values(by='Average Rating', ascending=True)
print(sorted_results)
#plot
least_rated_5 = sorted_results.head(5)
item_names = least_rated_5['Item Purchased'].to_numpy()
avg_ratings = least_rated_5['Average Rating'].to_numpy()
plt.figure(figsize=(8, 6))
plt.bar(item_names, avg_ratings)
plt.xlabel('Item Purchased')
plt.ylabel('Average Rating')
plt.title('Average Rating of Least Rated Items (Top 5)')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
#    Item Purchased  Average Rating
# 16          Shirt        3.629586
# 11          Jeans        3.648387
# 2          Blouse        3.683626
# 15          Scarf        3.700000
# 18         Shorts        3.711465
# 13          Pants        3.718713
# 9          Hoodie        3.719205
# 4            Coat        3.730435
# 22     Sunglasses        3.744720
# 17          Shoes        3.747333
# 21          Socks        3.750943
# 0        Backpack        3.752448
# 5           Dress        3.754819
# 12        Jewelry        3.756140
# 20       Sneakers        3.757931
# 1            Belt        3.761491
# 10         Jacket        3.763190
# 23        Sweater        3.767073
# 7         Handbag        3.775163
# 19          Skirt        3.782278
# 24        T-shirt        3.782993
# 8             Hat        3.806494
# 3           Boots        3.812500
# 14        Sandals        3.841250
# 6          Gloves        3.864286

# %%
plt.pie(results_avg, labels=results_avg.index, autopct="%1.1f%%", startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Total Purchase Amount per Item Purchased')
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Distribution of Purchase Amount
plt.figure(figsize=(10, 6))
sns.histplot(data['Purchase Amount (USD)'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Purchase Amount')
plt.xlabel('Purchase Amount (USD)')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of transaction frequency
plt.figure(figsize=(10, 6))
sns.countplot(x='Frequency of Purchases', data=data, palette='plasma')
plt.title('Distribution of Transaction Frequency')
plt.xlabel('Transaction Frequency')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-36-2863bd5f461c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Frequency of Purchases', data=data, palette='plasma')

# %%
# Customer demographics - Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True, color='green')
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Explore correlations between different variables (excluding categorical variables)
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = data[numerical_columns].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
summary_statistics = data.describe()
print("Summary Statistics:\n", summary_statistics)
# Out:
# Summary Statistics:
#         Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
product_sales = data.groupby('Item Purchased')['Purchase Amount (USD)'].sum().sort_values(ascending=False)

# %%
top_selling_products = product_sales.head(10)
print("Top Selling Products:\n", top_selling_products)
# Out:
# Top Selling Products:
#  Item Purchased
# Blouse        10410
# Shirt         10332
# Dress         10320
# Pants         10090
# Jewelry       10010
# Sunglasses     9649
# Belt           9635
# Scarf          9561
# Sweater        9462
# Shorts         9433
# Name: Purchase Amount (USD), dtype: int64

# %%
top_selling_categories = data[data['Item Purchased'].isin(top_selling_products.index)]['Category'].unique()
print("Categories of Top Selling Products:", top_selling_categories)
# Out:
# Categories of Top Selling Products: ['Clothing' 'Accessories']

# %%
category_sales = data.groupby('Category')['Purchase Amount (USD)'].sum().sort_values(ascending=False)

# %%
top_selling_categories = category_sales.head(5)
print("Top Selling Categories:\n", top_selling_categories)
# Out:
# Top Selling Categories:
#  Category
# Clothing       104264
# Accessories     74200
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=top_selling_categories.index, y=top_selling_categories.values, palette='pastel')
plt.title('Top Selling Categories')
plt.xlabel('Category')
plt.ylabel('Total Sales (USD)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-96ec538765e1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_selling_categories.index, y=top_selling_categories.values, palette='pastel')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=data, palette='pastel')
plt.title('Distribution of Customer Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-24-757bb784ab0a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=data, palette='pastel')

# %%
# Preferred payment methods
plt.figure(figsize=(8, 6))
sns.countplot(x='Payment Method', data=data, palette='pastel')
plt.title('Preferred Payment Methods')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-25-99cfea770e7e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Payment Method', data=data, palette='pastel')

# %%
average_age = data['Age'].mean()
most_common_payment_method = data['Payment Method'].mode()[0]

# %%
print("Average Age of Customers:", average_age)
print("Most Common Payment Method:", most_common_payment_method)
# Out:
# Average Age of Customers: 44.06846153846154
# Most Common Payment Method: PayPal

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool
